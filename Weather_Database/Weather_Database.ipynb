# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 761

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_desc = city_weather['weather'][0]['description']
        
            
        # Append the city information into the city_data list
        city_data.append({"City" : city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_desc,
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | coahuayana
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | ahipara
# Processing Record 6 of Set 1 | manjacaze
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | bitkine
# Processing Record 10 of Set 1 | madimba
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | havoysund
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | beringovskiy
# Processing Record 18 of Set 1 | darhan
# Processing Record 19 of Set 1 | altamira
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | rio gallegos
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | san matias
# Processing Record 26 of Set 1 | shingu
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | burica
# City not found. Skipping...
# Processing Record 29 of Set 1 | atar
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | narsaq
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 1 | kutum
# Processing Record 35 of Set 1 | coari
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | bundaberg
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | hurghada
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | esperance
# Processing Record 44 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 1 | ouadda
# Processing Record 46 of Set 1 | coihaique
# Processing Record 47 of Set 1 | xilagani
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | opuwo
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | quelimane
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | sao felix do xingu
# Processing Record 7 of Set 2 | kashi
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | camacha
# Processing Record 12 of Set 2 | teahupoo
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | manyana
# Processing Record 17 of Set 2 | laguna
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | mount gambier
# Processing Record 20 of Set 2 | poum
# Processing Record 21 of Set 2 | broken hill
# Processing Record 22 of Set 2 | babat
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | tomatlan
# Processing Record 26 of Set 2 | cayenne
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | gunjur
# Processing Record 29 of Set 2 | muros
# Processing Record 30 of Set 2 | vestmannaeyjar
# Processing Record 31 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | constitucion
# Processing Record 35 of Set 2 | mokhsogollokh
# Processing Record 36 of Set 2 | mogochin
# City not found. Skipping...
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | annamalainagar
# Processing Record 42 of Set 2 | teguldet
# Processing Record 43 of Set 2 | bowen
# Processing Record 44 of Set 2 | atmakur
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | san patricio
# Processing Record 47 of Set 2 | sabang
# Processing Record 48 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | bella union
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | svetlaya
# Processing Record 3 of Set 3 | vostok
# Processing Record 4 of Set 3 | bicaz chei
# Processing Record 5 of Set 3 | aykhal
# Processing Record 6 of Set 3 | tavda
# Processing Record 7 of Set 3 | novyy urengoy
# Processing Record 8 of Set 3 | tevaitoa
# Processing Record 9 of Set 3 | kolvereid
# Processing Record 10 of Set 3 | gabu
# Processing Record 11 of Set 3 | gubkinskiy
# Processing Record 12 of Set 3 | abatskoye
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | kuznechnoye
# Processing Record 15 of Set 3 | faanui
# Processing Record 16 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 3 | tomar
# Processing Record 18 of Set 3 | sao filipe
# Processing Record 19 of Set 3 | rocha
# Processing Record 20 of Set 3 | paredon
# Processing Record 21 of Set 3 | tochtepec
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | neuquen
# Processing Record 24 of Set 3 | santona
# Processing Record 25 of Set 3 | albany
# Processing Record 26 of Set 3 | niquelandia
# Processing Record 27 of Set 3 | hobart
# Processing Record 28 of Set 3 | mayo
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | tungor
# Processing Record 31 of Set 3 | bengkulu
# Processing Record 32 of Set 3 | severobaykalsk
# Processing Record 33 of Set 3 | santa ana
# Processing Record 34 of Set 3 | yerbogachen
# Processing Record 35 of Set 3 | friedland
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | huarmey
# Processing Record 38 of Set 3 | honningsvag
# Processing Record 39 of Set 3 | uruacu
# Processing Record 40 of Set 3 | chiang klang
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | parrita
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | saint-philippe
# Processing Record 46 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 3 | morant bay
# Processing Record 48 of Set 3 | joshimath
# Processing Record 49 of Set 3 | gilleleje
# Processing Record 50 of Set 3 | roald
# Processing Record 1 of Set 4 | mandalgovi
# Processing Record 2 of Set 4 | hua hin
# Processing Record 3 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 4 | benjamin hill
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 4 | port hardy
# Processing Record 7 of Set 4 | sibu
# Processing Record 8 of Set 4 | hamilton
# Processing Record 9 of Set 4 | vangaindrano
# Processing Record 10 of Set 4 | alta floresta
# Processing Record 11 of Set 4 | gamba
# Processing Record 12 of Set 4 | saint-pierre
# Processing Record 13 of Set 4 | cidreira
# Processing Record 14 of Set 4 | tynda
# Processing Record 15 of Set 4 | turukhansk
# Processing Record 16 of Set 4 | repnoye
# Processing Record 17 of Set 4 | thinadhoo
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | erenhot
# Processing Record 20 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 4 | panhala
# Processing Record 22 of Set 4 | narasapur
# Processing Record 23 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 4 | zyryanka
# Processing Record 25 of Set 4 | tabou
# Processing Record 26 of Set 4 | srednekolymsk
# Processing Record 27 of Set 4 | nago
# Processing Record 28 of Set 4 | upernavik
# Processing Record 29 of Set 4 | mao
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | fare
# Processing Record 32 of Set 4 | verkhoyansk
# Processing Record 33 of Set 4 | middelburg
# Processing Record 34 of Set 4 | chatakonda
# Processing Record 35 of Set 4 | port moresby
# Processing Record 36 of Set 4 | plaridel
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | daura
# Processing Record 39 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 40 of Set 4 | karratha
# Processing Record 41 of Set 4 | buritis
# Processing Record 42 of Set 4 | iqaluit
# Processing Record 43 of Set 4 | anchorage
# Processing Record 44 of Set 4 | husavik
# Processing Record 45 of Set 4 | jardim
# Processing Record 46 of Set 4 | butaritari
# Processing Record 47 of Set 4 | okato
# Processing Record 48 of Set 4 | la palma
# Processing Record 49 of Set 4 | taoudenni
# Processing Record 50 of Set 4 | haines junction
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | pevek
# Processing Record 3 of Set 5 | kirakira
# Processing Record 4 of Set 5 | caravelas
# Processing Record 5 of Set 5 | port macquarie
# Processing Record 6 of Set 5 | lokosovo
# Processing Record 7 of Set 5 | pathein
# Processing Record 8 of Set 5 | onega
# Processing Record 9 of Set 5 | codrington
# Processing Record 10 of Set 5 | paamiut
# Processing Record 11 of Set 5 | hofn
# Processing Record 12 of Set 5 | kibala
# Processing Record 13 of Set 5 | maple creek
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 5 | nikolskoye
# Processing Record 17 of Set 5 | los lunas
# Processing Record 18 of Set 5 | mehamn
# Processing Record 19 of Set 5 | araouane
# Processing Record 20 of Set 5 | kerchevskiy
# Processing Record 21 of Set 5 | longyearbyen
# Processing Record 22 of Set 5 | tasiilaq
# Processing Record 23 of Set 5 | gryfino
# Processing Record 24 of Set 5 | puerto ayacucho
# Processing Record 25 of Set 5 | korla
# Processing Record 26 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 5 | maniwaki
# Processing Record 28 of Set 5 | siderno
# Processing Record 29 of Set 5 | columbus
# Processing Record 30 of Set 5 | tessalit
# Processing Record 31 of Set 5 | godfrey
# Processing Record 32 of Set 5 | stokmarknes
# Processing Record 33 of Set 5 | pemberton
# Processing Record 34 of Set 5 | saint george
# Processing Record 35 of Set 5 | lusambo
# Processing Record 36 of Set 5 | maneadero
# Processing Record 37 of Set 5 | hervey bay
# Processing Record 38 of Set 5 | sorland
# Processing Record 39 of Set 5 | ajdabiya
# Processing Record 40 of Set 5 | kenitra
# Processing Record 41 of Set 5 | norman wells
# Processing Record 42 of Set 5 | sierpc
# Processing Record 43 of Set 5 | mersing
# Processing Record 44 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 5 | namatanai
# Processing Record 46 of Set 5 | salalah
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | christchurch
# Processing Record 49 of Set 5 | mariental
# Processing Record 50 of Set 5 | klaksvik
# Processing Record 1 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 6 | cabo san lucas
# Processing Record 3 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 6 | harlingen
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | bataipora
# Processing Record 7 of Set 6 | yamada
# Processing Record 8 of Set 6 | doembang nangbuat
# Processing Record 9 of Set 6 | hambantota
# Processing Record 10 of Set 6 | talcahuano
# Processing Record 11 of Set 6 | havelock
# Processing Record 12 of Set 6 | otradnoye
# Processing Record 13 of Set 6 | asau
# Processing Record 14 of Set 6 | dubrovka
# Processing Record 15 of Set 6 | uyemskiy
# Processing Record 16 of Set 6 | krasnoselkup
# Processing Record 17 of Set 6 | vanimo
# Processing Record 18 of Set 6 | kiama
# Processing Record 19 of Set 6 | meadow lake
# Processing Record 20 of Set 6 | tautira
# Processing Record 21 of Set 6 | nema
# Processing Record 22 of Set 6 | antofagasta
# Processing Record 23 of Set 6 | victoria
# Processing Record 24 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 6 | kuminskiy
# Processing Record 26 of Set 6 | liverpool
# Processing Record 27 of Set 6 | arman
# Processing Record 28 of Set 6 | kavarna
# Processing Record 29 of Set 6 | amparafaravola
# Processing Record 30 of Set 6 | jinji
# Processing Record 31 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 6 | grindavik
# Processing Record 34 of Set 6 | aden
# Processing Record 35 of Set 6 | bonthe
# Processing Record 36 of Set 6 | dikson
# Processing Record 37 of Set 6 | bucerias
# Processing Record 38 of Set 6 | rajanpur
# Processing Record 39 of Set 6 | quatre cocos
# Processing Record 40 of Set 6 | otofuke
# Processing Record 41 of Set 6 | lagoa
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | trairi
# Processing Record 44 of Set 6 | lujan
# Processing Record 45 of Set 6 | enumclaw
# Processing Record 46 of Set 6 | praia
# Processing Record 47 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | koslan
# Processing Record 49 of Set 6 | mackenzie
# Processing Record 50 of Set 6 | ketchikan
# Processing Record 1 of Set 7 | pandan
# Processing Record 2 of Set 7 | urusha
# Processing Record 3 of Set 7 | terrace
# Processing Record 4 of Set 7 | gazanjyk
# Processing Record 5 of Set 7 | saint anthony
# Processing Record 6 of Set 7 | maun
# Processing Record 7 of Set 7 | sola
# Processing Record 8 of Set 7 | bouar
# Processing Record 9 of Set 7 | nome
# Processing Record 10 of Set 7 | dowa
# Processing Record 11 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 7 | pedra azul
# Processing Record 13 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 7 | porto novo
# Processing Record 15 of Set 7 | dakoro
# Processing Record 16 of Set 7 | katsuura
# Processing Record 17 of Set 7 | hovd
# Processing Record 18 of Set 7 | asekeyevo
# Processing Record 19 of Set 7 | tiznit
# Processing Record 20 of Set 7 | kavieng
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | san cristobal
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | semirom
# Processing Record 26 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 27 of Set 7 | alexandria
# Processing Record 28 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 29 of Set 7 | meulaboh
# Processing Record 30 of Set 7 | egvekinot
# Processing Record 31 of Set 7 | yerraguntla
# Processing Record 32 of Set 7 | terra santa
# Processing Record 33 of Set 7 | capitao poco
# Processing Record 34 of Set 7 | laiagam
# City not found. Skipping...
# Processing Record 35 of Set 7 | davlekanovo
# Processing Record 36 of Set 7 | fairbanks
# Processing Record 37 of Set 7 | bandarbeyla
# Processing Record 38 of Set 7 | solnechnyy
# Processing Record 39 of Set 7 | guane
# Processing Record 40 of Set 7 | naze
# Processing Record 41 of Set 7 | ingham
# Processing Record 42 of Set 7 | chumikan
# Processing Record 43 of Set 7 | oistins
# Processing Record 44 of Set 7 | dingle
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | aklavik
# Processing Record 47 of Set 7 | portland
# Processing Record 48 of Set 7 | florianopolis
# Processing Record 49 of Set 7 | whittlesea
# Processing Record 50 of Set 7 | balangiga
# Processing Record 1 of Set 8 | nhamunda
# Processing Record 2 of Set 8 | ouesso
# Processing Record 3 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 8 | bethel
# Processing Record 5 of Set 8 | palauig
# Processing Record 6 of Set 8 | rudnya
# Processing Record 7 of Set 8 | okhotsk
# Processing Record 8 of Set 8 | invermere
# Processing Record 9 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 10 of Set 8 | general roca
# Processing Record 11 of Set 8 | chimoio
# Processing Record 12 of Set 8 | samarai
# Processing Record 13 of Set 8 | treia
# Processing Record 14 of Set 8 | barra patuca
# Processing Record 15 of Set 8 | maridi
# Processing Record 16 of Set 8 | bonavista
# Processing Record 17 of Set 8 | port lincoln
# Processing Record 18 of Set 8 | peniche
# Processing Record 19 of Set 8 | deputatskiy
# Processing Record 20 of Set 8 | corn island
# Processing Record 21 of Set 8 | faya
# Processing Record 22 of Set 8 | khammam
# Processing Record 23 of Set 8 | sayyan
# Processing Record 24 of Set 8 | tayu
# Processing Record 25 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 8 | melioratorov
# Processing Record 27 of Set 8 | silveira
# Processing Record 28 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 29 of Set 8 | ranghulu
# Processing Record 30 of Set 8 | east london
# Processing Record 31 of Set 8 | libertador general san martin
# Processing Record 32 of Set 8 | sept-iles
# Processing Record 33 of Set 8 | atambua
# Processing Record 34 of Set 8 | awbari
# Processing Record 35 of Set 8 | walvis bay
# Processing Record 36 of Set 8 | locri
# Processing Record 37 of Set 8 | ahar
# Processing Record 38 of Set 8 | arlit
# Processing Record 39 of Set 8 | sangar
# Processing Record 40 of Set 8 | stornoway
# Processing Record 41 of Set 8 | ixtapa
# Processing Record 42 of Set 8 | ola
# Processing Record 43 of Set 8 | cam ranh
# Processing Record 44 of Set 8 | mana
# Processing Record 45 of Set 8 | mbandaka
# Processing Record 46 of Set 8 | aksu
# Processing Record 47 of Set 8 | svetlogorsk
# Processing Record 48 of Set 8 | dasol
# Processing Record 49 of Set 8 | guerrero negro
# Processing Record 50 of Set 8 | talnakh
# Processing Record 1 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 9 | wangqing
# Processing Record 3 of Set 9 | kazachinskoye
# Processing Record 4 of Set 9 | umm lajj
# Processing Record 5 of Set 9 | jumla
# Processing Record 6 of Set 9 | shumskiy
# Processing Record 7 of Set 9 | mahebourg
# Processing Record 8 of Set 9 | vanino
# Processing Record 9 of Set 9 | baykit
# Processing Record 10 of Set 9 | hun
# Processing Record 11 of Set 9 | buenaventura
# Processing Record 12 of Set 9 | nianzishan
# Processing Record 13 of Set 9 | taltal
# Processing Record 14 of Set 9 | skibbereen
# Processing Record 15 of Set 9 | saint-georges
# Processing Record 16 of Set 9 | mount isa
# Processing Record 17 of Set 9 | pisco
# Processing Record 18 of Set 9 | launceston
# Processing Record 19 of Set 9 | axim
# Processing Record 20 of Set 9 | xingcheng
# Processing Record 21 of Set 9 | olafsvik
# Processing Record 22 of Set 9 | tuatapere
# Processing Record 23 of Set 9 | astipalaia
# City not found. Skipping...
# Processing Record 24 of Set 9 | limon
# Processing Record 25 of Set 9 | jalu
# Processing Record 26 of Set 9 | dusti
# Processing Record 27 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 9 | nioro
# Processing Record 29 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 9 | belaya gora
# Processing Record 31 of Set 9 | tsumeb
# Processing Record 32 of Set 9 | carndonagh
# Processing Record 33 of Set 9 | peleduy
# Processing Record 34 of Set 9 | omboue
# Processing Record 35 of Set 9 | ambon
# Processing Record 36 of Set 9 | marsh harbour
# Processing Record 37 of Set 9 | dabakala
# Processing Record 38 of Set 9 | hualmay
# Processing Record 39 of Set 9 | akdepe
# Processing Record 40 of Set 9 | campos altos
# Processing Record 41 of Set 9 | deoli
# Processing Record 42 of Set 9 | shimoda
# Processing Record 43 of Set 9 | dothan
# Processing Record 44 of Set 9 | burgeo
# Processing Record 45 of Set 9 | fortuna
# Processing Record 46 of Set 9 | lakatoro
# Processing Record 47 of Set 9 | mubi
# Processing Record 48 of Set 9 | inuvik
# Processing Record 49 of Set 9 | waddan
# Processing Record 50 of Set 9 | piazza armerina
# Processing Record 1 of Set 10 | andapa
# Processing Record 2 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 3 of Set 10 | bontang
# Processing Record 4 of Set 10 | marsa matruh
# Processing Record 5 of Set 10 | buenos aires
# Processing Record 6 of Set 10 | taraz
# Processing Record 7 of Set 10 | minbu
# Processing Record 8 of Set 10 | vardo
# Processing Record 9 of Set 10 | belyy yar
# Processing Record 10 of Set 10 | rawson
# Processing Record 11 of Set 10 | pinhao
# Processing Record 12 of Set 10 | ballina
# Processing Record 13 of Set 10 | vao
# Processing Record 14 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 10 | killybegs
# Processing Record 16 of Set 10 | rosita
# Processing Record 17 of Set 10 | chapleau
# Processing Record 18 of Set 10 | bairiki
# Processing Record 19 of Set 10 | xai-xai
# Processing Record 20 of Set 10 | punta alta
# Processing Record 21 of Set 10 | olinda
# Processing Record 22 of Set 10 | la ronge
# Processing Record 23 of Set 10 | skjervoy
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | broome
# Processing Record 26 of Set 10 | lieksa
# Processing Record 27 of Set 10 | oranjemund
# Processing Record 28 of Set 10 | bikin
# Processing Record 29 of Set 10 | borba
# Processing Record 30 of Set 10 | bemidji
# Processing Record 31 of Set 10 | nanortalik
# Processing Record 32 of Set 10 | thanh hoa
# Processing Record 33 of Set 10 | yar-sale
# Processing Record 34 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 10 | teya
# Processing Record 36 of Set 10 | tripoli
# Processing Record 37 of Set 10 | ghatanji
# Processing Record 38 of Set 10 | porbandar
# Processing Record 39 of Set 10 | mahibadhoo
# Processing Record 40 of Set 10 | shaki
# Processing Record 41 of Set 10 | ivdel
# Processing Record 42 of Set 10 | pangnirtung
# Processing Record 43 of Set 10 | zwedru
# Processing Record 44 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 10 | colares
# Processing Record 46 of Set 10 | upata
# Processing Record 47 of Set 10 | muisne
# Processing Record 48 of Set 10 | buenavista
# Processing Record 49 of Set 10 | puerto colombia
# Processing Record 50 of Set 10 | fallon
# Processing Record 1 of Set 11 | sungaipenuh
# Processing Record 2 of Set 11 | hanzhong
# Processing Record 3 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 4 of Set 11 | lixourion
# Processing Record 5 of Set 11 | cheyenne
# Processing Record 6 of Set 11 | nantucket
# Processing Record 7 of Set 11 | paris
# Processing Record 8 of Set 11 | yola
# Processing Record 9 of Set 11 | road town
# Processing Record 10 of Set 11 | nandyal
# Processing Record 11 of Set 11 | nong kung si
# Processing Record 12 of Set 11 | zvenigorod
# Processing Record 13 of Set 11 | buchanan
# Processing Record 14 of Set 11 | troitskoye
# Processing Record 15 of Set 11 | ludvika
# Processing Record 16 of Set 11 | russell
# Processing Record 17 of Set 11 | santiago de cao
# Processing Record 18 of Set 11 | evensk
# Processing Record 19 of Set 11 | huilong
# Processing Record 20 of Set 11 | kuytun
# Processing Record 21 of Set 11 | nelson bay
# Processing Record 22 of Set 11 | tibu
# Processing Record 23 of Set 11 | ermelo
# Processing Record 24 of Set 11 | algiers
# Processing Record 25 of Set 11 | skelleftea
# Processing Record 26 of Set 11 | padang
# Processing Record 27 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 11 | levelland
# Processing Record 29 of Set 11 | ukiah
# Processing Record 30 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | buraydah
# Processing Record 33 of Set 11 | san andres
# Processing Record 34 of Set 11 | bagnes
# Processing Record 35 of Set 11 | leh
# Processing Record 36 of Set 11 | hobyo
# Processing Record 37 of Set 11 | itarema
# Processing Record 38 of Set 11 | bayir
# Processing Record 39 of Set 11 | anderson
# Processing Record 40 of Set 11 | wadsworth
# Processing Record 41 of Set 11 | college
# Processing Record 42 of Set 11 | petatlan
# Processing Record 43 of Set 11 | chenzhou
# Processing Record 44 of Set 11 | kaniv
# Processing Record 45 of Set 11 | kamyshlov
# Processing Record 46 of Set 11 | huzhou
# Processing Record 47 of Set 11 | mizan teferi
# Processing Record 48 of Set 11 | hay river
# Processing Record 49 of Set 11 | cap malheureux
# Processing Record 50 of Set 11 | sarangani
# Processing Record 1 of Set 12 | upington
# Processing Record 2 of Set 12 | bilibino
# Processing Record 3 of Set 12 | kasongo-lunda
# Processing Record 4 of Set 12 | wattegama
# Processing Record 5 of Set 12 | san vicente
# Processing Record 6 of Set 12 | camocim
# Processing Record 7 of Set 12 | naberera
# Processing Record 8 of Set 12 | doha
# Processing Record 9 of Set 12 | necochea
# Processing Record 10 of Set 12 | apatou
# Processing Record 11 of Set 12 | apatity
# Processing Record 12 of Set 12 | fort nelson
# Processing Record 13 of Set 12 | dzilam gonzalez
# Processing Record 14 of Set 12 | baculin
# Processing Record 15 of Set 12 | havre-saint-pierre
# Processing Record 16 of Set 12 | aberdeen
# Processing Record 17 of Set 12 | kovdor
# Processing Record 18 of Set 12 | yumen
# Processing Record 19 of Set 12 | mapimi
# Processing Record 20 of Set 12 | port hedland
# Processing Record 21 of Set 12 | saryozek
# Processing Record 22 of Set 12 | sibolga
# Processing Record 23 of Set 12 | khanpur
# Processing Record 24 of Set 12 | killarney
# Processing Record 25 of Set 12 | keetmanshoop
# Processing Record 26 of Set 12 | linhares
# Processing Record 27 of Set 12 | oyama
# Processing Record 28 of Set 12 | flinders
# Processing Record 29 of Set 12 | simpang
# Processing Record 30 of Set 12 | bressuire
# Processing Record 31 of Set 12 | saint-francois
# Processing Record 32 of Set 12 | homestead
# Processing Record 33 of Set 12 | tezu
# Processing Record 34 of Set 12 | kalaleh
# Processing Record 35 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 12 | namibe
# Processing Record 37 of Set 12 | ust-ishim
# Processing Record 38 of Set 12 | ambato
# Processing Record 39 of Set 12 | sinnamary
# Processing Record 40 of Set 12 | saharsa
# Processing Record 41 of Set 12 | birjand
# Processing Record 42 of Set 12 | sabha
# Processing Record 43 of Set 12 | inhambane
# Processing Record 44 of Set 12 | homer
# Processing Record 45 of Set 12 | colac
# Processing Record 46 of Set 12 | independence
# Processing Record 47 of Set 12 | agadez
# Processing Record 48 of Set 12 | pitimbu
# Processing Record 49 of Set 12 | bollnas
# Processing Record 50 of Set 12 | puerto boyaca
# Processing Record 1 of Set 13 | cernat
# Processing Record 2 of Set 13 | matamoros
# Processing Record 3 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 13 | luanda
# Processing Record 5 of Set 13 | kimbe
# Processing Record 6 of Set 13 | khani
# Processing Record 7 of Set 13 | ruteng
# Processing Record 8 of Set 13 | flin flon
# Processing Record 9 of Set 13 | half moon bay
# Processing Record 10 of Set 13 | port blair
# Processing Record 11 of Set 13 | palmer
# Processing Record 12 of Set 13 | mareeba
# Processing Record 13 of Set 13 | naryan-mar
# Processing Record 14 of Set 13 | kurumkan
# Processing Record 15 of Set 13 | mildura
# Processing Record 16 of Set 13 | camamu
# Processing Record 17 of Set 13 | magalia
# Processing Record 18 of Set 13 | matiri
# Processing Record 19 of Set 13 | bolshaya dzhalga
# Processing Record 20 of Set 13 | kahului
# Processing Record 21 of Set 13 | villa corona
# Processing Record 22 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 13 | lianzhou
# Processing Record 24 of Set 13 | berlevag
# Processing Record 25 of Set 13 | kangaatsiaq
# Processing Record 26 of Set 13 | felanitx
# Processing Record 27 of Set 13 | seoul
# Processing Record 28 of Set 13 | nemuro
# Processing Record 29 of Set 13 | dawson creek
# Processing Record 30 of Set 13 | vanavara
# Processing Record 31 of Set 13 | sisimiut
# Processing Record 32 of Set 13 | kargasok
# Processing Record 33 of Set 13 | dongsheng
# Processing Record 34 of Set 13 | nouadhibou
# Processing Record 35 of Set 13 | dickinson
# Processing Record 36 of Set 13 | anloga
# Processing Record 37 of Set 13 | ushibuka
# Processing Record 38 of Set 13 | gilazi
# City not found. Skipping...
# Processing Record 39 of Set 13 | winfield
# Processing Record 40 of Set 13 | suileng
# Processing Record 41 of Set 13 | caohe
# Processing Record 42 of Set 13 | wajima
# Processing Record 43 of Set 13 | leningradskiy
# Processing Record 44 of Set 13 | veraval
# Processing Record 45 of Set 13 | emba
# Processing Record 46 of Set 13 | strezhevoy
# Processing Record 47 of Set 13 | carlagan
# Processing Record 48 of Set 13 | awjilah
# Processing Record 49 of Set 13 | lavrentiya
# Processing Record 50 of Set 13 | montepuez
# Processing Record 1 of Set 14 | rey bouba
# Processing Record 2 of Set 14 | djibo
# Processing Record 3 of Set 14 | lasa
# Processing Record 4 of Set 14 | san juan
# Processing Record 5 of Set 14 | sembe
# Processing Record 6 of Set 14 | nacogdoches
# Processing Record 7 of Set 14 | hasaki
# Processing Record 8 of Set 14 | kudahuvadhoo
# Processing Record 9 of Set 14 | tromso
# Processing Record 10 of Set 14 | mecca
# Processing Record 11 of Set 14 | barcelos
# Processing Record 12 of Set 14 | bhatapara
# Processing Record 13 of Set 14 | pekalongan
# Processing Record 14 of Set 14 | harper
# Processing Record 15 of Set 14 | bronnoysund
# Processing Record 16 of Set 14 | erdenet
# Processing Record 17 of Set 14 | canandaigua
# Processing Record 18 of Set 14 | junagarh
# Processing Record 19 of Set 14 | dunedin
# Processing Record 20 of Set 14 | biltine
# Processing Record 21 of Set 14 | townsville
# Processing Record 22 of Set 14 | alghero
# Processing Record 23 of Set 14 | tarabuco
# Processing Record 24 of Set 14 | skaerbaek
# Processing Record 25 of Set 14 | grand gaube
# Processing Record 26 of Set 14 | amga
# Processing Record 27 of Set 14 | borborema
# Processing Record 28 of Set 14 | guaiuba
# Processing Record 29 of Set 14 | wagar
# Processing Record 30 of Set 14 | henties bay
# Processing Record 31 of Set 14 | nenjiang
# Processing Record 32 of Set 14 | praia da vitoria
# Processing Record 33 of Set 14 | margate
# Processing Record 34 of Set 14 | northam
# Processing Record 35 of Set 14 | gravelbourg
# Processing Record 36 of Set 14 | marrakesh
# Processing Record 37 of Set 14 | san quintin
# Processing Record 38 of Set 14 | ulladulla
# Processing Record 39 of Set 14 | mafeteng
# Processing Record 40 of Set 14 | roebourne
# Processing Record 41 of Set 14 | trelew
# Processing Record 42 of Set 14 | esna
# Processing Record 43 of Set 14 | moose factory
# Processing Record 44 of Set 14 | richards bay
# Processing Record 45 of Set 14 | kaeo
# Processing Record 46 of Set 14 | kot addu
# Processing Record 47 of Set 14 | lata
# Processing Record 48 of Set 14 | maryborough
# Processing Record 49 of Set 14 | nhulunbuy
# Processing Record 50 of Set 14 | anadyr
# Processing Record 1 of Set 15 | mandali
# Processing Record 2 of Set 15 | provost
# Processing Record 3 of Set 15 | lerwick
# Processing Record 4 of Set 15 | altay
# Processing Record 5 of Set 15 | ust-kuyga
# Processing Record 6 of Set 15 | verkhnetulomskiy
# Processing Record 7 of Set 15 | baherden
# Processing Record 8 of Set 15 | terrell
# Processing Record 9 of Set 15 | yichun
# Processing Record 10 of Set 15 | geraldton
# Processing Record 11 of Set 15 | ardakan
# Processing Record 12 of Set 15 | sarakhs
# Processing Record 13 of Set 15 | plaster rock
# Processing Record 14 of Set 15 | north bend
# Processing Record 15 of Set 15 | chuguyevka
# Processing Record 16 of Set 15 | yulara
# Processing Record 17 of Set 15 | king city
# Processing Record 18 of Set 15 | kununurra
# Processing Record 19 of Set 15 | arkhangelos
# City not found. Skipping...
# Processing Record 20 of Set 15 | celestun
# Processing Record 21 of Set 15 | kenai
# Processing Record 22 of Set 15 | sao jose da coroa grande
# Processing Record 23 of Set 15 | pudozh
# Processing Record 24 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 15 | mitsamiouli
# Processing Record 26 of Set 15 | vitim
# Processing Record 27 of Set 15 | mormugao
# Processing Record 28 of Set 15 | marihatag
# Processing Record 29 of Set 15 | santa margherita ligure
# Processing Record 30 of Set 15 | mizdah
# Processing Record 31 of Set 15 | isangel
# Processing Record 32 of Set 15 | malakal
# Processing Record 33 of Set 15 | odweyne
# Processing Record 34 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 35 of Set 15 | ballitoville
# Processing Record 36 of Set 15 | maniitsoq
# Processing Record 37 of Set 15 | dharchula
# Processing Record 38 of Set 15 | soyo
# Processing Record 39 of Set 15 | gao
# Processing Record 40 of Set 15 | acarau
# Processing Record 41 of Set 15 | hami
# Processing Record 42 of Set 15 | jian
# Processing Record 43 of Set 15 | touros
# Processing Record 44 of Set 15 | pahrump
# Processing Record 45 of Set 15 | lewiston
# Processing Record 46 of Set 15 | gawler
# Processing Record 47 of Set 15 | hirara
# Processing Record 48 of Set 15 | matagami
# Processing Record 49 of Set 15 | umba
# Processing Record 50 of Set 15 | kondinskoye
# Processing Record 1 of Set 16 | bogorodskoye
# Processing Record 2 of Set 16 | bealanana
# Processing Record 3 of Set 16 | nawa
# Processing Record 4 of Set 16 | goleta
# Processing Record 5 of Set 16 | lesnoy
# Processing Record 6 of Set 16 | tooele
# Processing Record 7 of Set 16 | miri
# Processing Record 8 of Set 16 | neka
# Processing Record 9 of Set 16 | alofi
# Processing Record 10 of Set 16 | anaconda
# Processing Record 11 of Set 16 | annau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Coahuayana  18.7333 -103.6833     75.27        98         100
# 1       Mataura -46.1927  168.8643     47.48        45          91
# 2       Ushuaia -54.8000  -68.3000     40.66        81           0
# 3       Ahipara -35.1667  173.1667     61.03        85          65
# 4     Manjacaze -24.7117   33.8828     64.24        97           6
# 5  Punta Arenas -53.1500  -70.9167     42.91        65           0
# 6        Atuona  -9.8000 -139.0333     77.05        74          35
# 7       Bitkine  11.9801   18.2138     76.86        81          78
# 8       Madimba -10.4000   40.3333     67.98        88           4
# 9     Busselton -33.6500  115.3333     59.11        48          97
#
#    Wind Speed Country Current Description
# 0        2.46      MX     overcast clouds
# 1       10.07      NZ     overcast clouds
# 2        3.44      AR           clear sky
# 3       13.18      NZ       broken clouds
# 4        5.12      MZ           clear sky
# 5        9.22      CL           clear sky
# 6       18.86      PF          light rain
# 7        7.52      TD       broken clouds
# 8        3.69      TZ           clear sky
# 9       13.06      AU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Coahuayana      MX  18.7333 -103.6833     75.27        98         100
# 1       Mataura      NZ -46.1927  168.8643     47.48        45          91
# 2       Ushuaia      AR -54.8000  -68.3000     40.66        81           0
# 3       Ahipara      NZ -35.1667  173.1667     61.03        85          65
# 4     Manjacaze      MZ -24.7117   33.8828     64.24        97           6
# 5  Punta Arenas      CL -53.1500  -70.9167     42.91        65           0
# 6        Atuona      PF  -9.8000 -139.0333     77.05        74          35
# 7       Bitkine      TD  11.9801   18.2138     76.86        81          78
# 8       Madimba      TZ -10.4000   40.3333     67.98        88           4
# 9     Busselton      AU -33.6500  115.3333     59.11        48          97
#
#    Wind Speed Current Description
# 0        2.46     overcast clouds
# 1       10.07     overcast clouds
# 2        3.44           clear sky
# 3       13.18       broken clouds
# 4        5.12           clear sky
# 5        9.22           clear sky
# 6       18.86          light rain
# 7        7.52       broken clouds
# 8        3.69           clear sky
# 9       13.06     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
